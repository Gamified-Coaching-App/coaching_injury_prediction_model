# %%
import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from torch.utils.data import DataLoader, TensorDataset
import os
import time
from RunningDataset import RunningDataset

class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()
        
        # Encoder
        self.conv1 = nn.Conv2d(in_channels=10, out_channels=64, kernel_size=2, stride=1, padding='same')  # 'same' padding
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=16, kernel_size=2, stride=1, padding='same')  # 'same' padding
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

        # Bottleneck
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(256, 64)  # Adjusted from input (4*4*16 = 256)
        self.fc2 = nn.Linear(64, 5)
        self.fc3 = nn.Linear(5, 64)
        self.fc4 = nn.Linear(64, 256)

        # Decoder
        self.reshape = lambda x: x.view(-1, 16, 4, 4)  # Reshape to (None, 16, 4, 4)
        self.upsample = nn.Upsample(scale_factor=2, mode='nearest')  # Upsample to (None, 16, 8, 8)
        self.conv3 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=2, stride=1, padding='same')  # 'same' padding
        self.conv4 = nn.Conv2d(in_channels=16, out_channels=64, kernel_size=2, stride=1, padding='same')  # 'same' padding
        self.conv5 = nn.Conv2d(in_channels=64, out_channels=10, kernel_size=2, stride=1, padding='same')  # 'same' padding to match input channels
        
    def forward(self, x):
        x = self.encode(x)
        x = self.decode(x)
        return x
    
    def encode(self, x):
        # Encoder
        #print("Shape input for Layer 1: ", x.shape)
        x = F.selu(self.conv1(x))
        #print("Shape input for Layer 2", x.shape)
        x = F.selu(self.conv2(x))
        #print("Shape input for Layer 3", x.shape)
        x = self.pool(x)
        #print("Shape input for Layer 4", x.shape)
        # Bottleneck
        x = self.flatten(x)
        #print("Shape input for Layer 5", x.shape)
        x = self.fc1(x)
        #print("Shape input for Layer 6", x.shape)
        x = self.fc2(x)
        return x
    
    def decode(self,x):
        #print("Shape input for Layer 7", x.shape)
        x = self.fc3(x)
        #print("Shape input for Layer 8", x.shape)
        x = self.fc4(x)

        # Decoder
        #print("Shape input for Layer 9", x.shape)
        x = self.reshape(x)
        #print("Shape input for Layer 10", x.shape)
        x = self.upsample(x)
        #print("Shape input for Layer 11", x.shape)
        x = F.selu(self.conv3(x))
        #print("Shape input for Layer 12", x.shape)
        x = F.selu(self.conv4(x))
        #print("Shape input for Layer 13", x.shape)
        x = torch.tanh(self.conv5(x))
        #print("Shape output", x.shape)
        return x
    
    def train_model(self, train_loader, num_epochs=100, learning_rate=0.01):
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.to(device)
        optimizer = optim.Adadelta(self.parameters(), lr=learning_rate)
        criterion = nn.MSELoss()

        model_dir = 'saved_models'
        if not os.path.exists(model_dir):
            os.makedirs(model_dir)

        start = time.time()
        
        for epoch in range(num_epochs):
            self.train()
            total_loss = 0
            for data, _ in train_loader:
                data = data.to(device)

                # Forward pass
                outputs = self(data)
                loss = criterion(outputs, data)
                
                # Backward and optimize
                optimizer.zero_grad()
                loss.backward()

                optimizer.step()

                total_loss += loss.item()

            avg_loss = total_loss / len(train_loader)

            if (epoch+1) % 10 == 0:
                model_path = os.path.join(model_dir, f'autoencoder_epoch_{epoch+1}.pth')
                torch.save(self.state_dict(), model_path)
                print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}')

        print('Training completed in {:.3f} seconds.'.format(time.time() - start))
    
    def load_model(self, checkpoint_path):
        self.load_state_dict(torch.load(checkpoint_path))
        self.eval()  # Set the model to evaluation mode
    
    def encode_sample(self, X_sample):
        self.eval()  # Ensure the model is in evaluation mode
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        X_sample = X_sample.to(device)  # Move the sample to the same device as the model
        with torch.no_grad():
            encoded = self.encode(X_sample.unsqueeze(0))  # Add batch dimension
        return encoded

# %%
dataset = RunningDataset()
X_train, y_train, X_test, y_test = dataset.preprocess()
train_dataset = TensorDataset(X_train, X_train)  
train_loader = DataLoader(train_dataset, batch_size=512, shuffle=True)
model = Autoencoder()
model.train_model(train_loader)
# Out:
# No injured sample for Athlete ID 11
# No injured sample for Athlete ID 12
# No injured sample for Athlete ID 15
# No injured sample for Athlete ID 25
# No injured sample for Athlete ID 30
# No injured sample for Athlete ID 31
# No injured sample for Athlete ID 46
# No injured sample for Athlete ID 60
# No injured sample for Athlete ID 73
# Original series before clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.5 1.  0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.5 1.  0.5 0.5]
# Original series before clipping:
# [0. 0. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 0. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Series after clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0. 0. 0. 0. 0. 1. 0. 1.]
# Series after clipping:
# [0. 0. 0. 0. 0. 1. 0. 1.]
# Original series before clipping:
# [0.         0.41891892 0.         0.         0.         0.
#  1.         0.87837838]
# Series after clipping:
# [0.         0.41891892 0.         0.         0.         0.
#  1.         0.87837838]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 0. 0. 1. 0. 1.]
# Series after clipping:
# [0. 0. 0. 0. 0. 1. 0. 1.]
# Original series before clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Series after clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Original series before clipping:
# [0. 0. 0. 1. 0. 1. 0. 0.]
# Series after clipping:
# [0. 0. 0. 1. 0. 1. 0. 0.]
# Original series before clipping:
# [0.  0.5 0.5 0.  0.5 1.  0.5 1. ]
# Series after clipping:
# [0.  0.5 0.5 0.  0.5 1.  0.5 1. ]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.5 1.  0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.5 1.  0.5 0.5]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0.  0.5 0.  0.  1.  0.5 0.5 0.5]
# Series after clipping:
# [0.  0.5 0.  0.  1.  0.5 0.5 0.5]
# Original series before clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0. 0. 0. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 0. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 1. 0. 1. 0. 0.]
# Series after clipping:
# [0. 0. 0. 1. 0. 1. 0. 0.]
# Original series before clipping:
# [0.  0.5 0.5 0.  1.  1.  0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 0.  1.  1.  0.5 0.5]
# Original series before clipping:
# [0. 0. 0. 0. 1. 0. 1. 0.]
# Series after clipping:
# [0. 0. 0. 0. 1. 0. 1. 0.]
# Original series before clipping:
# [0.         0.41891892 0.         0.         0.         0.
#  1.         0.87837838]
# Series after clipping:
# [0.         0.41891892 0.         0.         0.         0.
#  1.         0.87837838]
# Original series before clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Series after clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Original series before clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Series after clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Original series before clipping:
# [0. 0. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 0. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0.  0.5 0.  0.  1.  0.5 1.  0.5]
# Series after clipping:
# [0.  0.5 0.  0.  1.  0.5 1.  0.5]
# Original series before clipping:
# [0.  0.5 0.  0.  1.  0.5 0.5 0.5]
# Series after clipping:
# [0.  0.5 0.  0.  1.  0.5 0.5 0.5]
# Original series before clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Series after clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Original series before clipping:
# [0.  0.5 0.5 0.  0.5 1.  0.5 1. ]
# Series after clipping:
# [0.  0.5 0.5 0.  0.5 1.  0.5 1. ]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 0. 1. 0. 1. 0.]
# Series after clipping:
# [0. 0. 0. 0. 1. 0. 1. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.5 1.  0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.5 1.  0.5 0.5]
# Original series before clipping:
# [0. 0. 0. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 0. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0. 1. 0. 0. 1. 1. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 1. 1. 0. 0.]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.  1.  0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.  1.  0.5 0.5]
# Original series before clipping:
# [0.  0.5 0.5 1.  0.5 0.5 0.  0.5]
# Series after clipping:
# [0.  0.5 0.5 1.  0.5 0.5 0.  0.5]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 1. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 1. 0.]
# Original series before clipping:
# [0. 0. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 0. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0.  0.  1.  0.5 0.  1.  0.5 0. ]
# Series after clipping:
# [0.  0.  1.  0.5 0.  1.  0.5 0. ]
# Original series before clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Series after clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Original series before clipping:
# [0.         1.         0.66216216 0.66216216 0.59459459 0.58108108
#  0.         0.72972973]
# Series after clipping:
# [0.         1.         0.66216216 0.66216216 0.59459459 0.58108108
#  0.         0.72972973]
# Original series before clipping:
# [0.  0.5 0.5 0.  1.  0.5 0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 0.  1.  0.5 0.5 0.5]
# Original series before clipping:
# [0. 0. 0. 1. 0. 1. 0. 0.]
# Series after clipping:
# [0. 0. 0. 1. 0. 1. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 1. 0. 1. 0. 0.]
# Series after clipping:
# [0. 0. 0. 1. 0. 1. 0. 0.]
# Original series before clipping:
# [0.  0.5 0.5 0.5 1.  0.5 0.5 1. ]
# Series after clipping:
# [0.  0.5 0.5 0.5 1.  0.5 0.5 1. ]
# Original series before clipping:
# [0. 0. 0. 1. 0. 1. 1. 0.]
# Series after clipping:
# [0. 0. 0. 1. 0. 1. 1. 0.]
# Original series before clipping:
# [0.         0.2826087  0.45652174 0.41304348 0.39130435 1.
#  0.93478261 0.45652174]
# Series after clipping:
# [0.         0.2826087  0.45652174 0.41304348 0.39130435 1.
#  0.93478261 0.45652174]
# Original series before clipping:
# [0. 0. 0. 0. 0. 1. 0. 0.]
# Series after clipping:
# [0. 0. 0. 0. 0. 1. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 0. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0.         0.62162162 1.         0.66216216 0.66216216 0.59459459
#  0.58108108 0.        ]
# Series after clipping:
# [0.         0.62162162 1.         0.66216216 0.66216216 0.59459459
#  0.58108108 0.        ]
# Original series before clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0.  0.5 0.5 1.  0.5 0.5 0.5 1. ]
# Series after clipping:
# [0.  0.5 0.5 1.  0.5 0.5 0.5 1. ]
# Original series before clipping:
# [0.         0.04950495 0.05940594 0.75247525 1.         0.
#  0.22772277 0.13861386]
# Series after clipping:
# [0.         0.04950495 0.05940594 0.75247525 1.         0.
#  0.22772277 0.13861386]
# Original series before clipping:
# [0. 0. 0. 1. 0. 1. 0. 0.]
# Series after clipping:
# [0. 0. 0. 1. 0. 1. 0. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 1. 0.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 1. 0.]
# Original series before clipping:
# [0. 0. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 0. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 0. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 0. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0.  0.5 1.  0.5 0.5 0.5 0.5 1. ]
# Series after clipping:
# [0.  0.5 1.  0.5 0.5 0.5 0.5 1. ]
# Original series before clipping:
# [0. 0. 0. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 0. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 0. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 0. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0.  0.  1.  0.  0.5 0.  0.5 0.5]
# Series after clipping:
# [0.  0.  1.  0.  0.5 0.  0.5 0.5]
# Original series before clipping:
# [0.  1.  0.5 0.5 0.5 0.  0.  1. ]
# Series after clipping:
# [0.  1.  0.5 0.5 0.5 0.  0.  1. ]
# Original series before clipping:
# [0. 1. 1. 0. 0. 0. 1. 0.]
# Series after clipping:
# [0. 1. 1. 0. 0. 0. 1. 0.]
# Original series before clipping:
# [0.         0.4950495  0.         0.34653465 1.         0.00990099
#  0.01980198 0.23762376]
# Series after clipping:
# [0.         0.4950495  0.         0.34653465 1.         0.00990099
#  0.01980198 0.23762376]
# Original series before clipping:
# [0.         0.83168317 0.7029703  1.         0.         0.66336634
#  0.54455446 0.        ]
# Series after clipping:
# [0.         0.83168317 0.7029703  1.         0.         0.66336634
#  0.54455446 0.        ]
# Original series before clipping:
# [0. 0. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 0. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 1. 0.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 1. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0.  1.  0.5 0.5 0.5 1.  0.5 0.5]
# Series after clipping:
# [0.  1.  0.5 0.5 0.5 1.  0.5 0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.5 1.  0.5 0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 0.5 1.  0.5 0.5 0.5]
# Original series before clipping:
# [0.         0.         1.         0.63369963 0.         0.56410256
#  0.42857143 0.        ]
# Series after clipping:
# [0.         0.         1.         0.63369963 0.         0.56410256
#  0.42857143 0.        ]
# Original series before clipping:
# [0. 0. 0. 0. 0. 1. 0. 1.]
# Series after clipping:
# [0. 0. 0. 0. 0. 1. 0. 1.]
# Original series before clipping:
# [0.  1.  0.5 0.5 0.5 0.  1.  0.5]
# Series after clipping:
# [0.  1.  0.5 0.5 0.5 0.  1.  0.5]
# Original series before clipping:
# [0. 0. 0. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 0. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0.  1.  0.5 0.  0.  0.  0.5 0. ]
# Series after clipping:
# [0.  1.  0.5 0.  0.  0.  0.5 0. ]
# Original series before clipping:
# [0.  1.  0.5 0.5 0.5 0.5 1.  0. ]
# Series after clipping:
# [0.  1.  0.5 0.5 0.5 0.5 1.  0. ]
# Original series before clipping:
# [0.  0.5 0.5 0.5 1.  0.5 0.5 0. ]
# Series after clipping:
# [0.  0.5 0.5 0.5 1.  0.5 0.5 0. ]
# Original series before clipping:
# [0. 0. 0. 0. 0. 1. 0. 0.]
# Series after clipping:
# [0. 0. 0. 0. 0. 1. 0. 0.]
# Original series before clipping:
# [0.  0.5 0.  1.  0.5 0.5 0.5 0.5]
# Series after clipping:
# [0.  0.5 0.  1.  0.5 0.5 0.5 0.5]
# Original series before clipping:
# [0.  0.5 0.5 1.  0.5 0.  0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 1.  0.5 0.  0.5 0.5]
# Original series before clipping:
# [0. 1. 0. 1. 1. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 1. 1. 0. 0. 0.]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.5 0.  1.  0. ]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.5 0.  1.  0. ]
# Original series before clipping:
# [0. 0. 0. 0. 0. 1. 0. 1.]
# Series after clipping:
# [0. 0. 0. 0. 0. 1. 0. 1.]
# Original series before clipping:
# [0.  1.  0.5 0.5 0.5 0.  0.5 0.5]
# Series after clipping:
# [0.  1.  0.5 0.5 0.5 0.  0.5 0.5]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 0. 0. 1. 0. 0.]
# Series after clipping:
# [0. 0. 0. 0. 0. 1. 0. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 0. 1. 1. 0.]
# Series after clipping:
# [0. 0. 1. 0. 0. 1. 1. 0.]
# Original series before clipping:
# [0. 0. 0. 0. 1. 0. 1. 0.]
# Series after clipping:
# [0. 0. 0. 0. 1. 0. 1. 0.]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.  1.  0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.  1.  0.5 0.5]
# Original series before clipping:
# [0.         1.         1.         0.75675676 0.01351351 0.82432432
#  0.77027027 0.60810811]
# Series after clipping:
# [0.         1.         1.         0.75675676 0.01351351 0.82432432
#  0.77027027 0.60810811]
# Original series before clipping:
# [0. 1. 0. 0. 0. 1. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 1. 0. 0.]
# Original series before clipping:
# [0.  0.5 0.  0.5 0.5 0.5 0.5 1. ]
# Series after clipping:
# [0.  0.5 0.  0.5 0.5 0.5 0.5 1. ]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0.  0.5 0.  0.5 0.5 0.5 1.  0.5]
# Series after clipping:
# [0.  0.5 0.  0.5 0.5 0.5 1.  0.5]
# Original series before clipping:
# [0.         0.28436019 0.         0.         0.         0.
#  1.         0.        ]
# Series after clipping:
# [0.         0.28436019 0.         0.         0.         0.
#  1.         0.        ]
# Original series before clipping:
# [0.  1.  0.5 0.5 0.5 0.5 0.  0. ]
# Series after clipping:
# [0.  1.  0.5 0.5 0.5 0.5 0.  0. ]
# Original series before clipping:
# [0.  0.  0.5 0.5 0.5 0.5 0.5 1. ]
# Series after clipping:
# [0.  0.  0.5 0.5 0.5 0.5 0.5 1. ]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0. 1. 1. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 1. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0.  0.5 1.  0.5 0.5 0.  0.  0. ]
# Series after clipping:
# [0.  0.5 1.  0.5 0.5 0.  0.  0. ]
# Original series before clipping:
# [0.  0.  0.5 0.5 1.  0.5 0.  0.5]
# Series after clipping:
# [0.  0.  0.5 0.5 1.  0.5 0.  0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.  0.  1.  0.5]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.  0.  1.  0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.5 1.  0.5 0.  0. ]
# Series after clipping:
# [0.  0.5 0.5 0.5 1.  0.5 0.  0. ]
# Original series before clipping:
# [0.         0.05940594 1.         0.14851485 0.22772277 0.
#  0.55445545 0.18811881]
# Series after clipping:
# [0.         0.05940594 1.         0.14851485 0.22772277 0.
#  0.55445545 0.18811881]
# Original series before clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0.   1.   0.14 0.38 0.2  0.87 0.2  0.49]
# Series after clipping:
# [0.   1.   0.14 0.38 0.2  0.87 0.2  0.49]
# Original series before clipping:
# [0. 0. 0. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 0. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0. 1. 0. 0. 1. 0. 1. 0.]
# Series after clipping:
# [0. 1. 0. 0. 1. 0. 1. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 0. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 0. 0. 1. 0. 0.]
# Series after clipping:
# [0. 0. 0. 0. 0. 1. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 0. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0.         0.83168317 0.82178218 1.         0.73267327 0.47524752
#  0.42574257 0.        ]
# Series after clipping:
# [0.         0.83168317 0.82178218 1.         0.73267327 0.47524752
#  0.42574257 0.        ]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0.         0.         0.13861386 0.         0.         0.
#  1.         0.00990099]
# Series after clipping:
# [0.         0.         0.13861386 0.         0.         0.
#  1.         0.00990099]
# Original series before clipping:
# [0.         0.78378378 0.60810811 0.59459459 0.62162162 0.62162162
#  1.         0.66216216]
# Series after clipping:
# [0.         0.78378378 0.60810811 0.59459459 0.62162162 0.62162162
#  1.         0.66216216]
# Original series before clipping:
# [0. 0. 0. 0. 0. 1. 0. 0.]
# Series after clipping:
# [0. 0. 0. 0. 0. 1. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 0. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0.  1.  0.5 0.5 0.  0.5 0.5 0. ]
# Series after clipping:
# [0.  1.  0.5 0.5 0.  0.5 0.5 0. ]
# Original series before clipping:
# [0. 0. 0. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 0. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 0. 0. 1. 0. 0.]
# Series after clipping:
# [0. 0. 0. 0. 0. 1. 0. 0.]
# Original series before clipping:
# [0.  1.  0.5 0.5 0.5 0.5 0.5 0.5]
# Series after clipping:
# [0.  1.  0.5 0.5 0.5 0.5 0.5 0.5]
# Original series before clipping:
# [0.         0.62162162 0.62162162 1.         0.66216216 0.66216216
#  0.59459459 0.58108108]
# Series after clipping:
# [0.         0.62162162 0.62162162 1.         0.66216216 0.66216216
#  0.59459459 0.58108108]
# Original series before clipping:
# [0.  0.  1.  1.  0.5 0.5 0.5 0.5]
# Series after clipping:
# [0.  0.  1.  1.  0.5 0.5 0.5 0.5]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 0. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0.         0.         0.63855422 0.62650602 0.65060241 1.
#  0.59036145 0.65060241]
# Series after clipping:
# [0.         0.         0.63855422 0.62650602 0.65060241 1.
#  0.59036145 0.65060241]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 0. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0.         0.56756757 0.         0.54054054 1.         1.
#  0.75675676 0.01351351]
# Series after clipping:
# [0.         0.56756757 0.         0.54054054 1.         1.
#  0.75675676 0.01351351]
# Original series before clipping:
# [0.         0.21782178 0.         0.05940594 1.         0.14851485
#  0.22772277 0.        ]
# Series after clipping:
# [0.         0.21782178 0.         0.05940594 1.         0.14851485
#  0.22772277 0.        ]
# Original series before clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.5 0.5 1.  0.5]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.5 0.5 1.  0.5]
# Original series before clipping:
# [0.  0.  1.  0.5 0.5 0.5 0.  1. ]
# Series after clipping:
# [0.  0.  1.  0.5 0.5 0.5 0.  1. ]
# Original series before clipping:
# [0.         0.35555556 0.         0.53333333 0.22222222 0.
#  1.         0.        ]
# Series after clipping:
# [0.         0.35555556 0.         0.53333333 0.22222222 0.
#  1.         0.        ]
# Original series before clipping:
# [0.  1.  0.5 0.  0.5 0.5 0.5 0.5]
# Series after clipping:
# [0.  1.  0.5 0.  0.5 0.5 0.5 0.5]
# Original series before clipping:
# [0.         0.         0.98019802 0.89108911 0.         0.0990099
#  0.         1.        ]
# Series after clipping:
# [0.         0.         0.98019802 0.89108911 0.         0.0990099
#  0.         1.        ]
# Original series before clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Series after clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0.         1.         0.24444444 0.35555556 0.         0.53333333
#  0.22222222 0.        ]
# Series after clipping:
# [0.         1.         0.24444444 0.35555556 0.         0.53333333
#  0.22222222 0.        ]
# Original series before clipping:
# [0.  0.  0.5 0.5 1.  0.5 1.  1. ]
# Series after clipping:
# [0.  0.  0.5 0.5 1.  0.5 1.  1. ]
# Original series before clipping:
# [0.  1.  0.5 0.5 0.  0.5 1.  0. ]
# Series after clipping:
# [0.  1.  0.5 0.5 0.  0.5 1.  0. ]
# Original series before clipping:
# [0. 0. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 0. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0.  1.  0.5 0.5 0.  1.  0.5 0.5]
# Series after clipping:
# [0.  1.  0.5 0.5 0.  1.  0.5 0.5]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0.  0.5 0.  0.5 0.5 0.5 1.  0.5]
# Series after clipping:
# [0.  0.5 0.  0.5 0.5 0.5 1.  0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.  1.  0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.  1.  0.5 0.5]
# Original series before clipping:
# [0.         1.         0.88732394 0.92957746 0.         0.35211268
#  0.         0.42253521]
# Series after clipping:
# [0.         1.         0.88732394 0.92957746 0.         0.35211268
#  0.         0.42253521]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 1. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 1. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0. 0. 0. 0. 0. 1. 0. 0.]
# Series after clipping:
# [0. 0. 0. 0. 0. 1. 0. 0.]
# Original series before clipping:
# [0.  1.  0.5 0.5 0.5 0.5 1.  0.5]
# Series after clipping:
# [0.  1.  0.5 0.5 0.5 0.5 1.  0.5]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0.         0.         0.49596774 0.29435484 1.         0.29435484
#  0.4516129  0.        ]
# Series after clipping:
# [0.         0.         0.49596774 0.29435484 1.         0.29435484
#  0.4516129  0.        ]
# Original series before clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Series after clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Original series before clipping:
# [0.  0.  1.  0.5 0.5 0.5 0.5 0. ]
# Series after clipping:
# [0.  0.  1.  0.5 0.5 0.5 0.5 0. ]
# Original series before clipping:
# [0. 1. 0. 0. 1. 0. 1. 0.]
# Series after clipping:
# [0. 1. 0. 0. 1. 0. 1. 0.]
# Original series before clipping:
# [0.         0.         0.16483516 0.21978022 0.         1.
#  0.63369963 0.        ]
# Series after clipping:
# [0.         0.         0.16483516 0.21978022 0.         1.
#  0.63369963 0.        ]
# Original series before clipping:
# [0. 0. 1. 0. 1. 1. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 1. 1. 0. 0.]
# Original series before clipping:
# [0.  0.5 1.  0.5 0.5 0.5 1.  0.5]
# Series after clipping:
# [0.  0.5 1.  0.5 0.5 0.5 1.  0.5]
# Original series before clipping:
# [0.         0.         1.         0.         0.23696682 0.
#  0.28436019 0.        ]
# Series after clipping:
# [0.         0.         1.         0.         0.23696682 0.
#  0.28436019 0.        ]
# Original series before clipping:
# [0.  0.5 0.5 0.  0.  1.  0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 0.  0.  1.  0.5 0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.  1.  1.  0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 0.  1.  1.  0.5 0.5]
# Original series before clipping:
# [0. 0. 0. 0. 1. 0. 1. 0.]
# Series after clipping:
# [0. 0. 0. 0. 1. 0. 1. 0.]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 1. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 1. 0.]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0.         0.59459459 0.         0.56756757 0.         0.54054054
#  1.         1.        ]
# Series after clipping:
# [0.         0.59459459 0.         0.56756757 0.         0.54054054
#  1.         1.        ]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0. 0. 0. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 0. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 0. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0.  1.  0.5 0.5 1.  0.5 0.5 0.5]
# Series after clipping:
# [0.  1.  0.5 0.5 1.  0.5 0.5 0.5]
# Original series before clipping:
# [0.         0.35714286 0.58333333 0.01190476 0.77380952 1.
#  0.         0.        ]
# Series after clipping:
# [0.         0.35714286 0.58333333 0.01190476 0.77380952 1.
#  0.         0.        ]
# Original series before clipping:
# [0.  0.5 0.5 0.  0.5 0.5 0.5 1. ]
# Series after clipping:
# [0.  0.5 0.5 0.  0.5 0.5 0.5 1. ]
# Original series before clipping:
# [0.  0.5 0.  0.5 0.5 0.5 0.5 1. ]
# Series after clipping:
# [0.  0.5 0.  0.5 0.5 0.5 0.5 1. ]
# Original series before clipping:
# [0.  0.5 0.5 0.  1.  0.5 0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 0.  1.  0.5 0.5 0.5]
# Original series before clipping:
# [0.         0.58333333 0.01190476 0.77380952 1.         0.
#  0.         0.53571429]
# Series after clipping:
# [0.         0.58333333 0.01190476 0.77380952 1.         0.
#  0.         0.53571429]
# Original series before clipping:
# [0.  0.  0.5 0.  0.  0.  1.  0.5]
# Series after clipping:
# [0.  0.  0.5 0.  0.  0.  1.  0.5]
# Original series before clipping:
# [0. 0. 1. 0. 0. 1. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 0. 1. 0. 0.]
# Original series before clipping:
# [0.  1.  0.5 0.5 0.  0.5 0.5 0.5]
# Series after clipping:
# [0.  1.  0.5 0.5 0.  0.5 0.5 0.5]
# Original series before clipping:
# [0. 0. 1. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 0. 0. 1. 0. 0.]
# Series after clipping:
# [0. 0. 0. 0. 0. 1. 0. 0.]
# Original series before clipping:
# [0.  0.  0.5 0.5 0.  1.  0.5 0.5]
# Series after clipping:
# [0.  0.  0.5 0.5 0.  1.  0.5 0.5]
# Original series before clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0.  0.  0.5 0.  0.5 0.5 1.  0.5]
# Series after clipping:
# [0.  0.  0.5 0.  0.5 0.5 1.  0.5]
# Original series before clipping:
# [0. 0. 0. 0. 0. 1. 0. 0.]
# Series after clipping:
# [0. 0. 0. 0. 0. 1. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 0. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0. 0. 0. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 0. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0.         0.39194139 0.         0.16483516 0.21978022 0.
#  1.         0.63369963]
# Series after clipping:
# [0.         0.39194139 0.         0.16483516 0.21978022 0.
#  1.         0.63369963]
# Original series before clipping:
# [0.  1.  0.5 0.5 0.5 1.  0.5 0.5]
# Series after clipping:
# [0.  1.  0.5 0.5 0.5 1.  0.5 0.5]
# Original series before clipping:
# [0.         1.         0.         0.23696682 0.         0.28436019
#  0.         0.09478673]
# Series after clipping:
# [0.         1.         0.         0.23696682 0.         0.28436019
#  0.         0.09478673]
# Original series before clipping:
# [0.  0.5 0.5 0.  1.  0.5 0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 0.  1.  0.5 0.5 0.5]
# Original series before clipping:
# [0. 0. 1. 1. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 1. 1. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 0. 0. 1. 0. 1.]
# Series after clipping:
# [0. 0. 0. 0. 0. 1. 0. 1.]
# Original series before clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0.         1.         0.29435484 0.4516129  0.         0.28225806
#  0.44758065 0.34677419]
# Series after clipping:
# [0.         1.         0.29435484 0.4516129  0.         0.28225806
#  0.44758065 0.34677419]
# Original series before clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Series after clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Original series before clipping:
# [0.         0.         0.         0.         0.63976608 0.
#  1.         0.        ]
# Series after clipping:
# [0.         0.         0.         0.         0.63976608 0.
#  1.         0.        ]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Series after clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Original series before clipping:
# [0. 0. 0. 0. 1. 0. 1. 0.]
# Series after clipping:
# [0. 0. 0. 0. 1. 0. 1. 0.]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0.  0.5 0.5 0.  0.5 1.  0.5 1. ]
# Series after clipping:
# [0.  0.5 0.5 0.  0.5 1.  0.5 1. ]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Series after clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0. 0. 0. 0. 0. 1. 0. 1.]
# Series after clipping:
# [0. 0. 0. 0. 0. 1. 0. 1.]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0.         1.         0.         0.         0.         0.
#  0.         0.29886041]
# Series after clipping:
# [0.         1.         0.         0.         0.         0.
#  0.         0.29886041]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0. 0. 0. 0. 0. 1. 0. 1.]
# Series after clipping:
# [0. 0. 0. 0. 0. 1. 0. 1.]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0.         0.41891892 0.         0.         0.         0.
#  1.         0.87837838]
# Series after clipping:
# [0.         0.41891892 0.         0.         0.         0.
#  1.         0.87837838]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0.         0.         0.         0.         0.         0.40284469
#  1.         0.        ]
# Series after clipping:
# [0.         0.         0.         0.         0.         0.40284469
#  1.         0.        ]
# Original series before clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 0. 0. 1. 0. 1.]
# Series after clipping:
# [0. 0. 0. 0. 0. 1. 0. 1.]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#  4.4229675e-04 1.0000000e+00 0.0000000e+00]
# Series after clipping:
# [0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#  4.4229675e-04 1.0000000e+00 0.0000000e+00]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0.         0.5        0.5        0.68987576 0.5        1.
#  0.5        0.5       ]
# Series after clipping:
# [0.         0.5        0.5        0.68987576 0.5        1.
#  0.5        0.5       ]
# Original series before clipping:
# [0.         0.41891892 0.         0.         0.         0.
#  1.         0.87837838]
# Series after clipping:
# [0.         0.41891892 0.         0.         0.         0.
#  1.         0.87837838]
# Original series before clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0.         0.         0.         0.         0.50718042 0.
#  1.         0.        ]
# Series after clipping:
# [0.         0.         0.         0.         0.50718042 0.
#  1.         0.        ]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0.         1.         0.         0.         0.         0.
#  0.         0.08357946]
# Series after clipping:
# [0.         1.         0.         0.         0.         0.
#  0.         0.08357946]
# Original series before clipping:
# [0.  0.5 0.5 0.  0.5 1.  0.5 1. ]
# Series after clipping:
# [0.  0.5 0.5 0.  0.5 1.  0.5 1. ]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0.       0.       0.       0.       0.728508 0.       1.       0.      ]
# Series after clipping:
# [0.       0.       0.       0.       0.728508 0.       1.       0.      ]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0.         0.         0.         1.         0.         0.94896765
#  0.         0.05103235]
# Series after clipping:
# [0.         0.         0.         1.         0.         0.94896765
#  0.         0.05103235]
# Original series before clipping:
# [0.         1.         0.         0.         0.         0.
#  0.         0.26563432]
# Series after clipping:
# [0.         1.         0.         0.         0.         0.
#  0.         0.26563432]
# Original series before clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Series after clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.5 1.  0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.5 1.  0.5 0.5]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 1. 0. 1. 0. 0.]
# Series after clipping:
# [0. 0. 0. 1. 0. 1. 0. 0.]
# Original series before clipping:
# [0.  0.5 0.  0.  1.  0.5 0.5 0.5]
# Series after clipping:
# [0.  0.5 0.  0.  1.  0.5 0.5 0.5]
# Original series before clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0.  0.5 0.5 0.  0.5 1.  0.5 1. ]
# Series after clipping:
# [0.  0.5 0.5 0.  0.5 1.  0.5 1. ]
# Original series before clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0.         0.         0.         0.         0.         0.04327957
#  1.         0.        ]
# Series after clipping:
# [0.         0.         0.         0.         0.         0.04327957
#  1.         0.        ]
# Original series before clipping:
# [0.         0.         0.         0.         0.         0.16937724
#  1.         0.        ]
# Series after clipping:
# [0.         0.         0.         0.         0.         0.16937724
#  1.         0.        ]
# Original series before clipping:
# [0.         0.         0.         0.         0.40070071 0.
#  1.         0.        ]
# Series after clipping:
# [0.         0.         0.         0.         0.40070071 0.
#  1.         0.        ]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0.         0.41891892 0.         0.         0.         0.
#  1.         0.87837838]
# Series after clipping:
# [0.         0.41891892 0.         0.         0.         0.
#  1.         0.87837838]
# Original series before clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Series after clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Series after clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 0. 1. 0. 1. 0.]
# Series after clipping:
# [0. 0. 0. 0. 1. 0. 1. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0.         1.         0.         0.         0.         0.
#  0.         0.09079786]
# Series after clipping:
# [0.         1.         0.         0.         0.         0.
#  0.         0.09079786]
# Original series before clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0.         1.         0.         0.80093872 0.         0.
#  0.         0.        ]
# Series after clipping:
# [0.         1.         0.         0.80093872 0.         0.
#  0.         0.        ]
# Original series before clipping:
# [0.         0.         0.         1.         0.         0.95541313
#  0.         0.04458687]
# Series after clipping:
# [0.         0.         0.         1.         0.         0.95541313
#  0.         0.04458687]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Series after clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Original series before clipping:
# [0. 0. 0. 1. 0. 1. 0. 0.]
# Series after clipping:
# [0. 0. 0. 1. 0. 1. 0. 0.]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0.         0.5        0.5        0.08274989 0.5        0.91725011
#  0.5        1.        ]
# Series after clipping:
# [0.         0.5        0.5        0.08274989 0.5        0.91725011
#  0.5        1.        ]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0.         1.         0.         0.         0.         0.
#  0.         0.43558341]
# Series after clipping:
# [0.         1.         0.         0.         0.         0.
#  0.         0.43558341]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0.         1.         0.         0.         0.         0.
#  0.         0.16252748]
# Series after clipping:
# [0.         1.         0.         0.         0.         0.
#  0.         0.16252748]
# Original series before clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Series after clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Original series before clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 0. 1. 0. 1. 0.]
# Series after clipping:
# [0. 0. 0. 0. 1. 0. 1. 0.]
# Original series before clipping:
# [0.         0.         0.         0.         0.94982465 0.
#  1.         0.        ]
# Series after clipping:
# [0.         0.         0.         0.         0.94982465 0.
#  1.         0.        ]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0.         0.         0.         0.         0.03326577 0.
#  1.         0.        ]
# Series after clipping:
# [0.         0.         0.         0.         0.03326577 0.
#  1.         0.        ]
# Original series before clipping:
# [0.         0.         0.         0.         0.         0.04533364
#  1.         0.        ]
# Series after clipping:
# [0.         0.         0.         0.         0.         0.04533364
#  1.         0.        ]
# Original series before clipping:
# [0.         0.         0.         0.         0.         0.34981283
#  1.         0.        ]
# Series after clipping:
# [0.         0.         0.         0.         0.         0.34981283
#  1.         0.        ]
# Original series before clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0.         1.         0.         0.59452832 0.         0.
#  0.         0.        ]
# Series after clipping:
# [0.         1.         0.         0.59452832 0.         0.
#  0.         0.        ]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0.         1.         0.         0.66285979 0.         0.
#  0.         0.        ]
# Series after clipping:
# [0.         1.         0.         0.66285979 0.         0.
#  0.         0.        ]
# Original series before clipping:
# [0.         0.         0.         0.         0.20488972 0.
#  1.         0.        ]
# Series after clipping:
# [0.         0.         0.         0.         0.20488972 0.
#  1.         0.        ]
# Original series before clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0.        1.        0.        0.7360354 0.        0.        0.
#  0.       ]
# Series after clipping:
# [0.        1.        0.        0.7360354 0.        0.        0.
#  0.       ]
# Original series before clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Series after clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Original series before clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 0. 1. 0. 1. 0.]
# Series after clipping:
# [0. 0. 0. 0. 1. 0. 1. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0. 0. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 0. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Series after clipping:
# [0. 0. 1. 0. 0. 0. 0. 1.]
# Original series before clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Series after clipping:
# [0. 0. 0. 0. 0. 0. 1. 0.]
# Original series before clipping:
# [0.         0.         0.         0.94717411 0.         1.
#  0.         0.05282589]
# Series after clipping:
# [0.         0.         0.         0.94717411 0.         1.
#  0.         0.05282589]
# Original series before clipping:
# [0.  0.5 0.  0.  1.  0.5 0.5 0.5]
# Series after clipping:
# [0.  0.5 0.  0.  1.  0.5 0.5 0.5]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Series after clipping:
# [0. 0. 1. 0. 1. 0. 0. 0.]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 1. 0. 0. 0. 0.]
# Original series before clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Series after clipping:
# [0. 1. 0. 0. 0. 0. 0. 0.]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.5 0.  0.5 1. ]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.5 0.  0.5 1. ]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.  0.5 1.  1. ]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.  0.5 1.  1. ]
# Original series before clipping:
# [0.  0.5 0.5 0.  0.5 1.  1.  1. ]
# Series after clipping:
# [0.  0.5 0.5 0.  0.5 1.  1.  1. ]
# Original series before clipping:
# [0.  0.5 0.  0.5 1.  1.  1.  1. ]
# Series after clipping:
# [0.  0.5 0.  0.5 1.  1.  1.  1. ]
# Original series before clipping:
# [0.  0.  0.5 1.  1.  1.  1.  0.5]
# Series after clipping:
# [0.  0.  0.5 1.  1.  1.  1.  0.5]
# Original series before clipping:
# [0.  0.5 1.  1.  1.  1.  0.5 1. ]
# Series after clipping:
# [0.  0.5 1.  1.  1.  1.  0.5 1. ]
# Original series before clipping:
# [0.  1.  1.  1.  1.  0.5 1.  0. ]
# Series after clipping:
# [0.  1.  1.  1.  1.  0.5 1.  0. ]
# Original series before clipping:
# [0.  1.  1.  1.  0.5 1.  0.  1. ]
# Series after clipping:
# [0.  1.  1.  1.  0.5 1.  0.  1. ]
# Original series before clipping:
# [0.  1.  1.  0.5 1.  0.  1.  0.5]
# Series after clipping:
# [0.  1.  1.  0.5 1.  0.  1.  0.5]
# Original series before clipping:
# [0.  1.  0.5 1.  0.  1.  0.5 1. ]
# Series after clipping:
# [0.  1.  0.5 1.  0.  1.  0.5 1. ]
# Original series before clipping:
# [0.  0.5 1.  0.  1.  0.5 1.  1. ]
# Series after clipping:
# [0.  0.5 1.  0.  1.  0.5 1.  1. ]
# Original series before clipping:
# [0.  1.  0.  1.  0.5 1.  1.  0.5]
# Series after clipping:
# [0.  1.  0.  1.  0.5 1.  1.  0.5]
# Original series before clipping:
# [0.  0.  1.  0.5 1.  1.  0.5 0.5]
# Series after clipping:
# [0.  0.  1.  0.5 1.  1.  0.5 0.5]
# Original series before clipping:
# [0.  1.  0.5 1.  1.  0.5 0.5 0. ]
# Series after clipping:
# [0.  1.  0.5 1.  1.  0.5 0.5 0. ]
# Original series before clipping:
# [0.  0.5 1.  1.  0.5 0.5 0.  0. ]
# Series after clipping:
# [0.  0.5 1.  1.  0.5 0.5 0.  0. ]
# ...
# [0.  0.  0.5 0.5 0.  1.  0.  0.5]
# Series after clipping:
# [0.  0.  0.5 0.5 0.  1.  0.  0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.  1.  0.  0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 0.  1.  0.  0.5 0.5]
# Original series before clipping:
# [0.  0.5 0.  1.  0.  0.5 0.5 0.5]
# Series after clipping:
# [0.  0.5 0.  1.  0.  0.5 0.5 0.5]
# Original series before clipping:
# [0.  0.  1.  0.  0.5 0.5 0.5 0.5]
# Series after clipping:
# [0.  0.  1.  0.  0.5 0.5 0.5 0.5]
# Original series before clipping:
# [0.  1.  0.  0.5 0.5 0.5 0.5 0.5]
# Series after clipping:
# [0.  1.  0.  0.5 0.5 0.5 0.5 0.5]
# Original series before clipping:
# [0.  0.  0.5 0.5 0.  0.5 0.5 1. ]
# Series after clipping:
# [0.  0.  0.5 0.5 0.  0.5 0.5 1. ]
# Original series before clipping:
# [0.  0.5 0.5 0.  0.5 0.5 1.  0.5]
# Series after clipping:
# [0.  0.5 0.5 0.  0.5 0.5 1.  0.5]
# Original series before clipping:
# [0.  0.5 0.  0.5 0.5 1.  0.5 0.5]
# Series after clipping:
# [0.  0.5 0.  0.5 0.5 1.  0.5 0.5]
# Original series before clipping:
# [0.  0.  0.5 0.5 1.  0.5 0.5 0.5]
# Series after clipping:
# [0.  0.  0.5 0.5 1.  0.5 0.5 0.5]
# Original series before clipping:
# [0.  0.5 0.5 1.  0.5 0.5 0.5 0. ]
# Series after clipping:
# [0.  0.5 0.5 1.  0.5 0.5 0.5 0. ]
# Original series before clipping:
# [0.  0.5 1.  0.5 0.5 0.5 0.  0.5]
# Series after clipping:
# [0.  0.5 1.  0.5 0.5 0.5 0.  0.5]
# Original series before clipping:
# [0.  1.  0.5 0.5 0.5 0.  0.5 0.5]
# Series after clipping:
# [0.  1.  0.5 0.5 0.5 0.  0.5 0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.  0.5 0.5 0.5 1. ]
# Series after clipping:
# [0.  0.5 0.5 0.  0.5 0.5 0.5 1. ]
# Original series before clipping:
# [0.  0.5 0.  0.5 0.5 0.5 1.  0.5]
# Series after clipping:
# [0.  0.5 0.  0.5 0.5 0.5 1.  0.5]
# Original series before clipping:
# [0.  0.  0.5 0.5 0.5 1.  0.5 0.5]
# Series after clipping:
# [0.  0.  0.5 0.5 0.5 1.  0.5 0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.5 1.  0.5 0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 0.5 1.  0.5 0.5 0.5]
# Original series before clipping:
# [0.  0.5 0.5 1.  0.5 0.5 0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 1.  0.5 0.5 0.5 0.5]
# Original series before clipping:
# [0.  0.5 1.  0.5 0.5 0.5 0.5 0. ]
# Series after clipping:
# [0.  0.5 1.  0.5 0.5 0.5 0.5 0. ]
# Original series before clipping:
# [0.  1.  0.5 0.5 0.5 0.5 0.  0.5]
# Series after clipping:
# [0.  1.  0.5 0.5 0.5 0.5 0.  0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.  0.5 0.5 1. ]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.  0.5 0.5 1. ]
# Original series before clipping:
# [0.  0.5 0.5 0.  0.5 0.5 1.  0. ]
# Series after clipping:
# [0.  0.5 0.5 0.  0.5 0.5 1.  0. ]
# Original series before clipping:
# [0.  0.5 0.  0.5 0.5 1.  0.  0.5]
# Series after clipping:
# [0.  0.5 0.  0.5 0.5 1.  0.  0.5]
# Original series before clipping:
# [0.  0.  0.5 0.5 1.  0.  0.5 0.5]
# Series after clipping:
# [0.  0.  0.5 0.5 1.  0.  0.5 0.5]
# Original series before clipping:
# [0.  0.5 0.5 1.  0.  0.5 0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 1.  0.  0.5 0.5 0.5]
# Original series before clipping:
# [0.  0.5 1.  0.  0.5 0.5 0.5 0.5]
# Series after clipping:
# [0.  0.5 1.  0.  0.5 0.5 0.5 0.5]
# Original series before clipping:
# [0.  1.  0.  0.5 0.5 0.5 0.5 0.5]
# Series after clipping:
# [0.  1.  0.  0.5 0.5 0.5 0.5 0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.5 0.5 0.5 1. ]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.5 0.5 0.5 1. ]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.5 0.5 1.  0.5]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.5 0.5 1.  0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.5 1.  0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.5 1.  0.5 0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.5 1.  0.5 0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 0.5 1.  0.5 0.5 0.5]
# Original series before clipping:
# [0.  0.5 0.5 1.  0.5 0.5 0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 1.  0.5 0.5 0.5 0.5]
# Original series before clipping:
# [0.  0.5 1.  0.5 0.5 0.5 0.5 0.5]
# Series after clipping:
# [0.  0.5 1.  0.5 0.5 0.5 0.5 0.5]
# Original series before clipping:
# [0.  1.  0.5 0.5 0.5 0.5 0.5 0.5]
# Series after clipping:
# [0.  1.  0.5 0.5 0.5 0.5 0.5 0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.5 0.  0.5 1. ]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.5 0.  0.5 1. ]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.  0.5 1.  0.5]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.  0.5 1.  0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.  0.5 1.  0.5 0. ]
# Series after clipping:
# [0.  0.5 0.5 0.  0.5 1.  0.5 0. ]
# Original series before clipping:
# [0.  0.5 0.  0.5 1.  0.5 0.  0.5]
# Series after clipping:
# [0.  0.5 0.  0.5 1.  0.5 0.  0.5]
# Original series before clipping:
# [0.  0.  0.5 1.  0.5 0.  0.5 0.5]
# Series after clipping:
# [0.  0.  0.5 1.  0.5 0.  0.5 0.5]
# Original series before clipping:
# [0.  0.5 1.  0.5 0.  0.5 0.5 0. ]
# Series after clipping:
# [0.  0.5 1.  0.5 0.  0.5 0.5 0. ]
# Original series before clipping:
# [0.  1.  0.5 0.  0.5 0.5 0.  0.5]
# Series after clipping:
# [0.  1.  0.5 0.  0.5 0.5 0.  0.5]
# Original series before clipping:
# [0.  0.5 0.  0.5 0.5 0.5 0.  1. ]
# Series after clipping:
# [0.  0.5 0.  0.5 0.5 0.5 0.  1. ]
# Original series before clipping:
# [0.  0.  0.5 0.5 0.5 0.  1.  0.5]
# Series after clipping:
# [0.  0.  0.5 0.5 0.5 0.  1.  0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.  1.  0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.  1.  0.5 0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.  1.  0.5 0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 0.  1.  0.5 0.5 0.5]
# Original series before clipping:
# [0.  0.5 0.  1.  0.5 0.5 0.5 0.5]
# Series after clipping:
# [0.  0.5 0.  1.  0.5 0.5 0.5 0.5]
# Original series before clipping:
# [0.  0.  1.  0.5 0.5 0.5 0.5 0.5]
# Series after clipping:
# [0.  0.  1.  0.5 0.5 0.5 0.5 0.5]
# Original series before clipping:
# [0.  1.  0.5 0.5 0.5 0.5 0.5 0. ]
# Series after clipping:
# [0.  1.  0.5 0.5 0.5 0.5 0.5 0. ]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.5 0.5 0.  1. ]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.5 0.5 0.  1. ]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.5 0.  1.  0.5]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.5 0.  1.  0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.  1.  0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.  1.  0.5 0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.  1.  0.5 0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 0.  1.  0.5 0.5 0.5]
# Original series before clipping:
# [0.  0.5 0.  1.  0.5 0.5 0.5 0.5]
# Series after clipping:
# [0.  0.5 0.  1.  0.5 0.5 0.5 0.5]
# Original series before clipping:
# [0.  0.  1.  0.5 0.5 0.5 0.5 0.5]
# Series after clipping:
# [0.  0.  1.  0.5 0.5 0.5 0.5 0.5]
# Original series before clipping:
# [0.  1.  0.5 0.5 0.5 0.5 0.5 0. ]
# Series after clipping:
# [0.  1.  0.5 0.5 0.5 0.5 0.5 0. ]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.5 0.5 0.  1. ]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.5 0.5 0.  1. ]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.5 0.  1.  0.5]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.5 0.  1.  0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.  1.  0.5 0. ]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.  1.  0.5 0. ]
# Original series before clipping:
# [0.  0.5 0.5 0.  1.  0.5 0.  0.5]
# Series after clipping:
# [0.  0.5 0.5 0.  1.  0.5 0.  0.5]
# Original series before clipping:
# [0.  0.5 0.  1.  0.5 0.  0.5 0. ]
# Series after clipping:
# [0.  0.5 0.  1.  0.5 0.  0.5 0. ]
# Original series before clipping:
# [0.  0.  1.  0.5 0.  0.5 0.  0.5]
# Series after clipping:
# [0.  0.  1.  0.5 0.  0.5 0.  0.5]
# Original series before clipping:
# [0.  1.  0.5 0.  0.5 0.  0.5 0.5]
# Series after clipping:
# [0.  1.  0.5 0.  0.5 0.  0.5 0.5]
# Original series before clipping:
# [0.  0.5 1.  0.5 0.5 0.5 0.  0.5]
# Series after clipping:
# [0.  0.5 1.  0.5 0.5 0.5 0.  0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.5 0.5 0.  1. ]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.5 0.5 0.  1. ]
# Original series before clipping:
# [0.  0.5 0.  0.5 0.5 0.5 0.5 1. ]
# Series after clipping:
# [0.  0.5 0.  0.5 0.5 0.5 0.5 1. ]
# Original series before clipping:
# [0.  0.  0.5 0.5 0.5 0.5 1.  0.5]
# Series after clipping:
# [0.  0.  0.5 0.5 0.5 0.5 1.  0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.5 1.  0.5 0. ]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.5 1.  0.5 0. ]
# Original series before clipping:
# [0.  0.5 0.5 0.5 1.  0.5 0.  0.5]
# Series after clipping:
# [0.  0.5 0.5 0.5 1.  0.5 0.  0.5]
# Original series before clipping:
# [0.  0.5 0.5 1.  0.5 0.  0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 1.  0.5 0.  0.5 0.5]
# Original series before clipping:
# [0.  0.5 1.  0.5 0.  0.5 0.5 0.5]
# Series after clipping:
# [0.  0.5 1.  0.5 0.  0.5 0.5 0.5]
# Original series before clipping:
# [0.  1.  0.5 0.  0.5 0.5 0.5 0.5]
# Series after clipping:
# [0.  1.  0.5 0.  0.5 0.5 0.5 0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.  0.5 0.5 1. ]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.  0.5 0.5 1. ]
# Original series before clipping:
# [0.  0.5 0.5 0.  0.5 0.5 1.  1. ]
# Series after clipping:
# [0.  0.5 0.5 0.  0.5 0.5 1.  1. ]
# Original series before clipping:
# [0.  0.5 0.  0.5 0.5 1.  1.  0.5]
# Series after clipping:
# [0.  0.5 0.  0.5 0.5 1.  1.  0.5]
# Original series before clipping:
# [0.  0.  0.5 0.5 1.  1.  0.5 0.5]
# Series after clipping:
# [0.  0.  0.5 0.5 1.  1.  0.5 0.5]
# Original series before clipping:
# [0.  0.5 0.5 1.  1.  0.5 0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 1.  1.  0.5 0.5 0.5]
# Original series before clipping:
# [0.  0.5 1.  1.  0.5 0.5 0.5 0. ]
# Series after clipping:
# [0.  0.5 1.  1.  0.5 0.5 0.5 0. ]
# Original series before clipping:
# [0.  1.  1.  0.5 0.5 0.5 0.  0.5]
# Series after clipping:
# [0.  1.  1.  0.5 0.5 0.5 0.  0.5]
# Original series before clipping:
# [0.  1.  0.5 0.5 0.5 0.  0.5 0.5]
# Series after clipping:
# [0.  1.  0.5 0.5 0.5 0.  0.5 0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.5 0.  0.5 1. ]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.5 0.  0.5 1. ]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.  0.5 1.  0.5]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.  0.5 1.  0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.  0.5 1.  0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 0.  0.5 1.  0.5 0.5]
# Original series before clipping:
# [0.  0.5 0.  0.5 1.  0.5 0.5 0.5]
# Series after clipping:
# [0.  0.5 0.  0.5 1.  0.5 0.5 0.5]
# Original series before clipping:
# [0.  0.  0.5 1.  0.5 0.5 0.5 0. ]
# Series after clipping:
# [0.  0.  0.5 1.  0.5 0.5 0.5 0. ]
# Original series before clipping:
# [0.  0.5 1.  0.5 0.5 0.5 0.  0.5]
# Series after clipping:
# [0.  0.5 1.  0.5 0.5 0.5 0.  0.5]
# Original series before clipping:
# [0.  1.  0.5 0.5 0.5 0.  0.5 0.5]
# Series after clipping:
# [0.  1.  0.5 0.5 0.5 0.  0.5 0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.  1.  0.5 0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 0.  1.  0.5 0.5 0.5]
# Original series before clipping:
# [0.  0.5 0.  1.  0.5 0.5 0.5 0. ]
# Series after clipping:
# [0.  0.5 0.  1.  0.5 0.5 0.5 0. ]
# Original series before clipping:
# [0.  0.  1.  0.5 0.5 0.5 0.  0.5]
# Series after clipping:
# [0.  0.  1.  0.5 0.5 0.5 0.  0.5]
# Original series before clipping:
# [0.  1.  0.5 0.5 0.5 0.  0.5 0.5]
# Series after clipping:
# [0.  1.  0.5 0.5 0.5 0.  0.5 0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.5 0.5 0.  1. ]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.5 0.5 0.  1. ]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.5 0.  1.  0.5]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.5 0.  1.  0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.  1.  0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.  1.  0.5 0.5]
# Original series before clipping:
# [0.  0.5 0.5 0.  1.  0.5 0.5 0.5]
# Series after clipping:
# [0.  0.5 0.5 0.  1.  0.5 0.5 0.5]
# Original series before clipping:
# [0.  0.5 0.  1.  0.5 0.5 0.5 0.5]
# Series after clipping:
# [0.  0.5 0.  1.  0.5 0.5 0.5 0.5]
# Original series before clipping:
# [0.  0.  1.  0.5 0.5 0.5 0.5 0.5]
# Series after clipping:
# [0.  0.  1.  0.5 0.5 0.5 0.5 0.5]
# Original series before clipping:
# [0.  1.  0.5 0.5 0.5 0.5 0.5 0. ]
# Series after clipping:
# [0.  1.  0.5 0.5 0.5 0.5 0.5 0. ]
# Original series before clipping:
# [0.  0.  0.5 0.5 1.  0.5 0.  0. ]
# Series after clipping:
# [0.  0.  0.5 0.5 1.  0.5 0.  0. ]
# Original series before clipping:
# [0.  0.5 0.5 1.  0.5 0.  0.  0.5]
# Series after clipping:
# [0.  0.5 0.5 1.  0.5 0.  0.  0.5]
# Original series before clipping:
# [0.  0.5 1.  0.5 0.  0.  0.5 0.5]
# Series after clipping:
# [0.  0.5 1.  0.5 0.  0.  0.5 0.5]
# Original series before clipping:
# [0.  1.  0.5 0.  0.  0.5 0.5 0. ]
# Series after clipping:
# [0.  1.  0.5 0.  0.  0.5 0.5 0. ]
# Original series before clipping:
# [0.  0.5 0.5 0.5 0.  0.5 0.5 1. ]
# Series after clipping:
# [0.  0.5 0.5 0.5 0.  0.5 0.5 1. ]
# Original series before clipping:
# [0.  0.5 0.5 0.  0.5 0.5 1.  0. ]
# Series after clipping:
# [0.  0.5 0.5 0.  0.5 0.5 1.  0. ]
# Original series before clipping:
# [0.  0.5 0.  0.5 0.5 1.  0.  0.5]
# Series after clipping:
# [0.  0.5 0.  0.5 0.5 1.  0.  0.5]
# Original series before clipping:
# [0.  0.  0.5 0.5 1.  0.  0.5 0. ]
# Series after clipping:
# [0.  0.  0.5 0.5 1.  0.  0.5 0. ]
# Original series before clipping:
# [0.  0.5 0.5 1.  0.  0.5 0.  0. ]
# Series after clipping:
# [0.  0.5 0.5 1.  0.  0.5 0.  0. ]
# Original series before clipping:
# [0.  0.5 1.  0.  0.5 0.  0.  0. ]
# Series after clipping:
# [0.  0.5 1.  0.  0.5 0.  0.  0. ]
# Original series before clipping:
# [0.  1.  0.  0.5 0.  0.  0.  0. ]
# Series after clipping:
# [0.  1.  0.  0.5 0.  0.  0.  0. ]
# Original series before clipping:
# [0.         1.         0.42574257 0.94059406 0.81188119 0.
#  0.88118812 0.86138614]
# Series after clipping:
# [0.         1.         0.42574257 0.94059406 0.81188119 0.
#  0.88118812 0.86138614]
# Original series before clipping:
# [0.         0.         0.67901235 0.96296296 0.2962963  0.11111111
#  0.         1.        ]
# Series after clipping:
# [0.         0.         0.67901235 0.96296296 0.2962963  0.11111111
#  0.         1.        ]
# Original series before clipping:
# [0.         0.67901235 0.96296296 0.2962963  0.11111111 0.
#  1.         0.33333333]
# Series after clipping:
# [0.         0.67901235 0.96296296 0.2962963  0.11111111 0.
#  1.         0.33333333]
# Original series before clipping:
# [0.         0.96296296 0.2962963  0.11111111 0.         1.
#  0.33333333 0.        ]
# Series after clipping:
# [0.         0.96296296 0.2962963  0.11111111 0.         1.
#  0.33333333 0.        ]
# Original series before clipping:
# [0.         0.2962963  0.11111111 0.         1.         0.33333333
#  0.         0.64197531]
# Series after clipping:
# [0.         0.2962963  0.11111111 0.         1.         0.33333333
#  0.         0.64197531]
# Original series before clipping:
# [0.         0.11111111 0.         1.         0.33333333 0.
#  0.64197531 0.54320988]
# Series after clipping:
# [0.         0.11111111 0.         1.         0.33333333 0.
#  0.64197531 0.54320988]
# Original series before clipping:
# [0.         0.         1.         0.33333333 0.         0.64197531
#  0.54320988 0.51851852]
# Series after clipping:
# [0.         0.         1.         0.33333333 0.         0.64197531
#  0.54320988 0.51851852]
# Original series before clipping:
# [0.         1.         0.33333333 0.         0.64197531 0.54320988
#  0.51851852 0.50617284]
# Series after clipping:
# [0.         1.         0.33333333 0.         0.64197531 0.54320988
#  0.51851852 0.50617284]
# Shapes of the datasets: X_train: torch.Size([9464, 10, 8, 8]) y_train: torch.Size([9464]) X_test: torch.Size([6839, 10, 8, 8]) y_test: torch.Size([6839])
# /Users/gabriel/blaze/coaching/coaching_injury_model/venv_coaching_01/lib/python3.12/site-packages/torch/nn/modules/conv.py:456: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Convolution.cpp:1032.)
#   return F.conv2d(input, weight, bias, self.stride,
# Epoch [10/100], Loss: 0.2119
# Epoch [20/100], Loss: 0.1172
# Epoch [30/100], Loss: 0.1028
# Epoch [40/100], Loss: 0.0981
# Epoch [50/100], Loss: 0.0950
# Epoch [60/100], Loss: 0.0932
# Epoch [70/100], Loss: 0.0910
# Epoch [80/100], Loss: 0.0894
# Epoch [90/100], Loss: 0.0876
# Epoch [100/100], Loss: 0.0853
# Training completed in 231.650 seconds.

# %%
model = Autoencoder()
model.load_model('saved_models/autoencoder_epoch_100.pth')
print(model.encode_sample(X_train[0]))
# Out:
# tensor([[ 2.2906, -2.4428,  0.8046, -0.1086,  1.8486]])
