# %%
from RunningDataset import RunningDataset
dataset = RunningDataset()
dataset.preprocess()
# Out:
# Shape data before cleaning:  (42766, 73)
# Shape data after cleaning:  (42766, 73)
# Training Data - Injury counts: injury
# 0    39189
# 1      533
# Name: count, dtype: int64
# Testing Data - Injury counts: injury
# 0    2994
# 1      50
# Name: count, dtype: int64
# Number of samples after balanced sampling:  78378
# Number of injuries (1) after balanced sampling: 39189
# Number of non-injuries (0) after balanced sampling: 39189
# Number of samples after unbalanced sampling:  8800
# Number of injuries (1) after unbalanced sampling: 800
# Number of non-injuries (0) after unbalanced sampling: 8000
# Shapes of the datasets: X_train: (15998, 8, 8, 10) y_train: (15998,) X_test: (3044, 8, 8, 10) y_test: (3044,)
# (<tf.Tensor: shape=(15998, 8, 8, 10), dtype=float32, numpy=
#  array([[[[-1.00000000e+00, -1.00000000e+00, -1.00000000e+00, ...,
#            -1.00000000e+00, -1.00000000e+00, -1.00000000e+00],
#           [-1.00000000e+00, -1.00000000e+00, -1.00000000e+00, ...,
# ...

# %%
pd.set_option('display.max_columns', None)
dataset.X_train.head()
# Out:
#    nr. sessions.0  total km.0  km Z3-4.0  km Z5-T1-T2.0  km sprinting.0  \
# 0             0.0    0.000000   0.000000            0.0             0.0
# 1             0.5    0.332326   0.236967            0.0             0.0
# 2             1.0    0.628755   0.000000            0.0             0.0
# 3             0.0    0.000000   0.000000            0.0             0.0
# 4             0.5    0.338983   0.236967            0.0             0.0
#
#    strength training.0  hours alternative.0  perceived exertion.0  \
# 0                  0.0                  0.0              0.000000
# 1                  0.0                  0.0              0.011111
# 2                  0.0                  0.0              0.452381
# 3                  0.0                  0.0              0.000000
# 4                  0.0                  0.0              0.921875
#
#    perceived trainingSuccess.0  perceived recovery.0  nr. sessions.1  \
# ...

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
array = dataset.X_train.iloc[100, [1, 11, 21, 31, 41, 51, 61]]
array = np.concatenate([[0], array])
print(array)
array = scaler.fit_transform(array.reshape(-1, 1))
array = array.flatten()
arccos = np.arccos(array)
field = [a + b for a in arccos for b in arccos]
gram = np.cos(field).reshape(8, 8)
print(np.round(gram,2))
# Out:
# [0.         0.46857143 0.33714286 0.50285714 0.         0.20285714
#  0.43428571 0.47142857]
# [[-1.   -0.36 -0.74  0.   -1.   -0.92 -0.5  -0.35]
#  [-0.36  0.74  0.36  0.93 -0.36  0.04  0.62  0.75]
#  [-0.74  0.36 -0.1   0.67 -0.74 -0.41  0.21  0.37]
#  [ 0.    0.93  0.67  1.    0.    0.4   0.86  0.94]
#  [-1.   -0.36 -0.74  0.   -1.   -0.92 -0.5  -0.35]
#  [-0.92  0.04 -0.41  0.4  -0.92 -0.67 -0.11  0.06]
#  [-0.5   0.62  0.21  0.86 -0.5  -0.11  0.49  0.63]
#  [-0.35  0.75  0.37  0.94 -0.35  0.06  0.63  0.76]]

# %%
print(dataset.X_train.iloc[1, [1, 11, 21, 31, 41, 51, 61]])
# Out:
# total km.0    0.332326
# total km.1    0.000000
# total km.2    0.000000
# total km.3    0.528701
# total km.4    0.377644
# total km.5    0.241692
# total km.6    0.392749
# Name: 1, dtype: float64

# %%
print(np.round(dataset.X_gasf_train[100, :,:, 1],2))
# Out:
# [[-1.   -0.36 -0.74  0.   -1.   -0.92 -0.5  -0.35]
#  [-0.36  0.74  0.36  0.93 -0.36  0.04  0.62  0.75]
#  [-0.74  0.36 -0.1   0.67 -0.74 -0.41  0.21  0.37]
#  [ 0.    0.93  0.67  1.    0.    0.4   0.86  0.94]
#  [-1.   -0.36 -0.74  0.   -1.   -0.92 -0.5  -0.35]
#  [-0.92  0.04 -0.41  0.4  -0.92 -0.67 -0.11  0.06]
#  [-0.5   0.62  0.21  0.86 -0.5  -0.11  0.49  0.63]
#  [-0.35  0.75  0.37  0.94 -0.35  0.06  0.63  0.76]]

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 10, figsize=(20, 2))  # Adjust the number of subplots based on the number of metrics
for i in range(10):  # Assuming 10 metrics
    axes[i].imshow(dataset.X_gasf_train[120][:, :, i], cmap='viridis')
    axes[i].set_title(f'Metric {i+1}')
    axes[i].axis('off')
plt.show()

# %%
from preprocessor import Preprocessor
preprocessor = Preprocessor()
X_train, y_train, X_test, y_test = preprocessor.preprocess()
# Out:
# Shape data before cleaning:  (42766, 73)
# Shape data after cleaning:  (42766, 73)
# Training Data - Injury counts: injury
# 0    39189
# 1      533
# Name: count, dtype: int64
# Testing Data - Injury counts: injury
# 0    2994
# 1      50
# Name: count, dtype: int64
# Number of samples after balanced sampling:  78378
# Number of injuries (1) after balanced sampling: 39189
# Number of non-injuries (0) after balanced sampling: 39189
# Number of samples after unbalanced sampling:  5429
# Number of injuries (1) after unbalanced sampling: 650
# Number of non-injuries (0) after unbalanced sampling: 4779
# Number of samples after Tomek Links:  5388
# Number of injuries (1) after Tomek Links: 650
# Number of non-injuries (0) after Tomek Links: 4738
# Number of samples after SMOTE:  9476
# Number of injuries (1) after SMOTE: 4738
# Number of non-injuries (0) after SMOTE: 4738
# Shapes of the datasets: X_train: (9476, 7, 10) y_train: (9476,) X_test: (3044, 7, 10) y_test: (3044,)

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
data = preprocessor.reorder_columns(preprocessor.X_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 pd.set_option('display.max_columns', None)
# ----> 3 data = preprocessor.reorder_columns(preprocessor.X_train)
#
# NameError: name 'preprocessor' is not defined

# %%
print(preprocessor.X_restructure_train[0, :, 0])
# Out:
# [0.  0.5 0.5 0.  0.5 0.5 0.5]

# %%
from classifier_lstm import run_and_evaluate
run_and_evaluate(X_train, y_train, X_test, y_test)
# Out:
# /Users/gabriel/blaze/coaching/coaching_injury_prediction_model/venv_coaching_02/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 16/16 - 1s - 91ms/step - loss: 0.0217
# 16/16 - 0s - 8ms/step - loss: 0.0217
# 16/16 - 0s - 15ms/step - loss: 0.0216
# 16/16 - 0s - 9ms/step - loss: 0.0216
# 16/16 - 0s - 7ms/step - loss: 0.0216
# 16/16 - 0s - 8ms/step - loss: 0.0216
# 16/16 - 0s - 7ms/step - loss: 0.0216
# 16/16 - 0s - 7ms/step - loss: 0.0216
# 16/16 - 0s - 8ms/step - loss: 0.0216
# 16/16 - 0s - 8ms/step - loss: 0.0216
# 16/16 - 0s - 8ms/step - loss: 0.0216
# 16/16 - 0s - 7ms/step - loss: 0.0216
# 16/16 - 0s - 7ms/step - loss: 0.0216
# 16/16 - 0s - 8ms/step - loss: 0.0216
# 16/16 - 0s - 7ms/step - loss: 0.0216
# 16/16 - 0s - 8ms/step - loss: 0.0216
# ...
